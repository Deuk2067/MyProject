# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

import numpy as np
import pandas as pd
import time

# %%
targetSite = 'https://series.naver.com/novel/top100List.series' 
driver = webdriver.Chrome() 
driver.get(targetSite)
time.sleep(0.5)

for i in range (1,5,1): # 실시간, 일간, 주간, 월간
    driver.find_element(By.XPATH, f'//*[@id="container"]/div[1]/ul/li[{i}]/a').click()
    time.sleep(1)
    
    Titles = [] # 제목 저장할 리스트
    Genre = [] # 장르 저장할 리스트
    Author = [] # 작가 저장할 리스트
    Start = [] # 연재 시작일
    Last = [] # 마지막 연재일
    Count = [] # 연재수
    Good = [] # 추천수
    Point = [] # 평점
    Comment = [] # 댓글 수
    
    for p in range(1,6,1):
        if p == 1: # 첫 페이지 1~20위
            continue
        else: # p가 2부터5까지
            driver.find_element(By.XPATH, f'//*[@id="content"]/div/div[2]/a[{p-1}]').click() # 2, 3, 4, 5
            
        for j in range(1, 21, 1):
            # 1~20위, 21~40, 41~60 소설 클릭
            driver.find_element(By.XPATH, f'//*[@id="content"]/div/ul/li[{j}]/div[2]/h3/a').click() # j번째 소설 들어감

            if "login" in driver.current_url or "adult" in driver.current_url: # 19금, 로그인 필요한 경우
                # 이후 전처리 할 떄 쉽게 하도록 19금 통일
                Titles.append("19금")
                Genre.append("19금")
                Author.append("19금")            
                Point.append("19금")
                Start.append("19금")
                Last.append("19금")
                Count.append("19금")
                Good.append("19금")
                Comment.append("19금")
                driver.back()
                continue
        
            # 정렬 기준이 랜덤이라 Start, Last에 들어가는게 반대로 들어가는 경우가 있음 (최신순, 1화부터) 
            a=driver.find_element(By.XPATH, '//*[@id="content"]/table/thead/tr/th[1]/div') # 최신순
            b=driver.find_element(By.XPATH, '//*[@id="content"]/table/thead/tr/th[2]/div') # 1화부터

            if a.get_attribute('class') == 'on _changeTicketSortOrder(DESC)': # 내림차순 정렬, 최신순 정렬되있는 경우
                time.sleep(0.5)
                Last.append(driver.find_element(By.XPATH, '//*[@id="volumeList"]/tr[1]/td[1]/em').text) # 마지막 연재일  
                time.sleep(0.5)
                b.click() # 1화부터 체크 => 올림차순 정렬 1화부터 정렬
                time.sleep(0.5)
                Start.append(driver.find_element(By.XPATH, '//*[@id="volumeList"]/tr[1]/td[1]/em').text) # 연재 시작일 추가
                driver.back() # 뒤로 돌아감 = 다시 내림차순 정렬, 최신순 정렬로 돌아감

            elif b.get_attribute('class') == 'on _changeTicketSortOrder(ASC)': # 올림차순 정렬, 1화부터 정렬되 있을 경우
                time.sleep(0.5)
                Start.append(driver.find_element(By.XPATH, '//*[@id="volumeList"]/tr[1]/td[1]/em').text) # 연재 시작일 추가
                time.sleep(0.5)
                a.click() # 최신순부터 체크 => 내림차순 정렬 최신화부터 정렬
                time.sleep(0.5)
                Last.append(driver.find_element(By.XPATH, '//*[@id="volumeList"]/tr[1]/td[1]/em').text) # 마지막 연재일  
                driver.back() # 뒤로 돌아감 = 다시 올림차순 정렬, 1화부터 정렬
            
            try:
                Titles.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[1]/h2').text) # 제목
                Good.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[1]/div[2]/ul/li[2]/div/a/em').text) # 추천수
            except:
                Titles.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/h2').text) # 제목
                Good.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div[2]/ul/li[2]/div/a/em').text) # 추천수
            try:
                Point.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[1]/div[1]/em').text) # 평점
            except:
                Point.append(driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div[1]/em').text) # 평점
            Genre.append(driver.find_element(By.XPATH, '//*[@id="content"]/ul[1]/li/ul/li[2]/span/a').text) # 장르
            Author.append(driver.find_element(By.XPATH, '//*[@id="content"]/ul[1]/li/ul/li[3]/a').text) # 작가
            Count.append(driver.find_element(By.XPATH, '//*[@id="content"]/h5/strong').text) # 연재수

            time.sleep(1)
            Comment.append(driver.find_element(By.XPATH, '//*[@id="cbox_module"]/div/div[1]/span').text)
            #print(len(Titles), len(Genre), len(Author), len(Start), len(Last), len(Count), len(Comment), len(Good), len(Point))
            print(f'{j}. 제목: {Titles[j-1]}, 장르: {Genre[j-1]}, 작가: {Author[j-1]}, 시작일: {Start[j-1]}, 최신화: {Last[j-1]}, 연재수: {Count[j-1]}, 추천수: {Good[j-1]}, 평점: {Point[j-1]}, 댓글: {Comment[j-1]}')
            driver.back()# i번 소설 크로링 후 전 페이지로    
    
    df= pd.DataFrame({"제목":Titles, "장르":Genre, "작가":Author, "연재 시작일":Start, "마지막 연재일":Last, "회수":Count, "댓글수":Comment, "추천수":Good, "평점": Point})
    df.index = df.index+1
    
    if i == 1:
        df.to_csv('./data/NSeries_Now.txt')
    if i == 2:
        df.to_csv('./data/NSeries_Today.txt')
    if i == 3:
        df.to_csv('./data/NSeries_Week.txt')
    else:
        df.to_csv('./data/NSeries_Month.txt')
# Out:
# 제목: 멜팅 슬로우 [독점], 장르: 로맨스, 작가: 이른꽃, 시작일: (2023.02.07.), 최신화: (2023.04.01.), 연재수: 92, 추천수: 101, 평점: 9.8, 댓글: 3,912
# 제목: 회귀자 생활백서(回歸者 生活白書), 장르: 무협, 작가: 넉울히, 시작일: (2024.05.23.), 최신화: (2024.06.23.), 연재수: 157, 추천수: 12, 평점: 9.2, 댓글: 1,524
# 제목: 국세청 망나니 [독점], 장르: 현판, 작가: 동면거북이, 시작일: (2020.07.08.), 최신화: (2022.01.06.), 연재수: 500, 추천수: 327, 평점: 9.7, 댓글: 16,103
# 제목: 전직용병 재벌서자 [독점], 장르: 현판, 작가: 꾼밤, 시작일: (2023.10.24.), 최신화: (2024.06.24.), 연재수: 284, 추천수: 28, 평점: 9.2, 댓글: 2,143
# 제목: 회귀 경찰의 리셋 라이프, 장르: 현판, 작가: 한길, 시작일: (2024.06.24.), 최신화: (2024.06.24.), 연재수: 1039, 추천수: 좋아요, 평점: 8.2, 댓글: 2
# 제목: 천마신교 최강 막내제자 [독점], 장르: 무협, 작가: 리진, 시작일: (2022.04.27.), 최신화: (2022.12.15.), 연재수: 300, 추천수: 25, 평점: 8.5, 댓글: 978
# 제목: 가짜 연애 [독점], 장르: 로맨스, 작가: 임여리, 시작일: (2023.08.25.), 최신화: (2024.01.01.), 연재수: 96, 추천수: 35, 평점: 8.5, 댓글: 668
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8840\315698442.py in <module>
#      79
#      80             time.sleep(0.5)
# ---> 81             Comment.append(driver.find_element(By.XPATH, '//*[@id="cbox_module"]/div/div[1]/span').text)
#      82
#      83             #print(len(Titles), len(Genre), len(Author), len(Start), len(Last), len(Count), len(Comment), len(Good), len(Point))
#
# C:\anaconda3\envs\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     737             value = f'[name="{value}"]'
#     738
# --> 739         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     740
#     741     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# C:\anaconda3\envs\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
# --> 345             self.error_handler.check_response(response)
#     346             response["value"] = self._unwrap_value(response.get("value", None))
#     347             return response
#
# C:\anaconda3\envs\python37\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="cbox_module"]/div/div[1]/span"}
#   (Session info: chrome=126.0.6478.63); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF673E03E32+31618]
# 	(No symbol) [0x00007FF673D7B099]
# 	(No symbol) [0x00007FF673C3888A]
# 	(No symbol) [0x00007FF673C88524]
# 	(No symbol) [0x00007FF673C8862C]
# 	(No symbol) [0x00007FF673CCF787]
# 	(No symbol) [0x00007FF673CAD14F]
# 	(No symbol) [0x00007FF673CCCA80]
# 	(No symbol) [0x00007FF673CACEB3]
# 	(No symbol) [0x00007FF673C7A46B]
# 	(No symbol) [0x00007FF673C7B001]
# 	GetHandleVerifier [0x00007FF674109FFD+3202381]
# 	GetHandleVerifier [0x00007FF674156A1D+3516269]
# 	GetHandleVerifier [0x00007FF67414C490+3473888]
# 	GetHandleVerifier [0x00007FF673EB5D36+760454]
# 	(No symbol) [0x00007FF673D86B3F]
# 	(No symbol) [0x00007FF673D81CD4]
# 	(No symbol) [0x00007FF673D81E62]
# 	(No symbol) [0x00007FF673D7120F]
# 	BaseThreadInitThunk [0x00007FFF084F7344+20]
# 	RtlUserThreadStart [0x00007FFF0A3DCC91+33]

# %%
dfN=pd.read_csv('./data/NSeries_Now.txt', index_col=0)
dfT=pd.read_csv('./data/NSeries_Today.txt', index_col=0)
dfW=pd.read_csv('./data/NSeries_Week.txt', index_col=0)
dfM=pd.read_csv('./data/NSeries_Month.txt', index_col=0)

# %%
dfN

# %%
dfT

# %%
dfW

# %%
dfM
