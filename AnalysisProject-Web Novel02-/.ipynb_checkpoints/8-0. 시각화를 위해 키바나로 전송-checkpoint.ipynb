# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False
import pandas as pd
from elasticsearch import Elasticsearch, helpers

# %%
es = Elasticsearch('http://localhost:9200')
df = pd.read_csv('./data/All_Novel.txt', index_col=0, parse_dates=['마지막 연재일', '연재 시작일'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9734 entries, 0 to 9733
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   제목       9734 non-null   object
#  1   장르       9734 non-null   object
#  2   작가       9734 non-null   object
#  3   연재수      9734 non-null   int64
#  4   연재 시작일   9734 non-null   datetime64[ns]
#  5   마지막 연재일  9734 non-null   datetime64[ns]
#  6   Site     9734 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 608.4+ KB

# %%
# orient='records' 를 사용해서 df의 행하나를 컬럼을 키값으로 가지고
#  행 하나를 value로 같는 리스트 형태의 딕셔너리를 만듬
docs = df.to_dict(orient='records') 
print(docs[0])
print(docs[0]['제목'])
print(len(docs))
print(docs[0].keys())
# Out:
# {'제목': ' 차라리 빌런으로 살겠다', '장르': '현대판타지', '작가': '서인하', '연재수': 127, '연재 시작일': Timestamp('2024-03-02 00:00:00'), '마지막 연재일': Timestamp('2024-06-25 00:00:00'), 'Site': 'Munpia'}
#  차라리 빌런으로 살겠다
# 9734
# dict_keys(['제목', '장르', '작가', '연재수', '연재 시작일', '마지막 연재일', 'Site'])

# %%
doc_list = []
i = 0
for dic in docs:
    i+=1

    doc = {
        '_index': 'web_novels',
        '_source': {
            'Title': dic['제목'],
            'Genre': dic['장르'],
            'Author': dic['작가'],
            'Count': dic['연재수'],
            'Site': dic['Site'],
            'period': {
                'start': dic['연재 시작일'],
                'last': dic['마지막 연재일']
            }
        }
    }
    doc_list.append(doc)

helpers.bulk(es, doc_list)
# Out:
# (9734, [])

# %%
es = Elasticsearch('http://localhost:9200')
kdf = pd.read_csv('./data/K_all.txt', index_col=0, parse_dates=['마지막 연재일', '연재 시작일'])
kdf.info()
kdocs = kdf.to_dict(orient='records')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2260 entries, 0 to 2259
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   제목       2260 non-null   object
#  1   장르       2260 non-null   object
#  2   작가       2260 non-null   object
#  3   조회수      2260 non-null   int64
#  4   댓글       2260 non-null   int64
#  5   연재수      2260 non-null   int64
#  6   연재 시작일   2260 non-null   datetime64[ns]
#  7   마지막 연재일  2260 non-null   datetime64[ns]
#  8   평점       2260 non-null   float64
#  9   Site     2260 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(4)
# memory usage: 194.2+ KB

# %%
i = 0
for kdoc in kdocs:
    i += 1
    es.index(index='kakao_novels', id=i, body=kdoc)

# %%
es = Elasticsearch('http://localhost:9200')
mdf = pd.read_csv('./data/M_all.txt', index_col=0, parse_dates=['마지막 연재일', '연재 시작일'])
mdf.info()
mdocs = mdf.to_dict(orient='records')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1310 entries, 0 to 1309
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   제목       1310 non-null   object
#  1   장르       1310 non-null   object
#  2   작가       1310 non-null   object
#  3   연재 시작일   1310 non-null   datetime64[ns]
#  4   마지막 연재일  1310 non-null   datetime64[ns]
#  5   연재수      1310 non-null   int64
#  6   조회수      1310 non-null   int64
#  7   추천수      1310 non-null   int64
#  8   글자수      1310 non-null   int64
#  9   선작수      1310 non-null   int64
#  10  Site     1310 non-null   object
# dtypes: datetime64[ns](2), int64(5), object(4)
# memory usage: 122.8+ KB

# %%
i = 0
for mdoc in mdocs:
    i+=1
    es.index(index='munpia_novels', id=i, body=mdoc)

# %%
es = Elasticsearch('http://localhost:9200')
ndf = pd.read_csv('./data/N_all.txt', index_col=0, parse_dates=['마지막 연재일', '연재 시작일'])
ndf.info()
ndocs = ndf.to_dict(orient='records')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6767 entries, 0 to 6766
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   제목       6767 non-null   object
#  1   장르       6767 non-null   object
#  2   작가       6767 non-null   object
#  3   연재 시작일   6767 non-null   datetime64[ns]
#  4   마지막 연재일  6767 non-null   datetime64[ns]
#  5   연재수      6767 non-null   int64
#  6   댓글수      6767 non-null   int64
#  7   추천수      6767 non-null   int64
#  8   평점       6767 non-null   float64
#  9   Site     6767 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(4)
# memory usage: 581.5+ KB

# %%
ndoc_list = []
i = 0
for ndic in ndocs:
    i+=1

    ndoc = {
        '_index': 'naverseries_novels',
        '_source': {
            'Title': ndic['제목'],
            'Genre': ndic['장르'],
            'Author': ndic['작가'],
            'Count': ndic['연재수'],
            'Comments': ndic['댓글수'],
            'Favorite': ndic['추천수'],
            'Ratings': ndic['평점'],
            'Site': ndic['Site'],
            'period': {
                'start': ndic['연재 시작일'],
                'last': ndic['마지막 연재일']
            }
        }
    }
    ndoc_list.append(ndoc)

helpers.bulk(es, ndoc_list)
# Out:
# (6767, [])

# %%
df = pd.read_csv('./data/All_Novel.txt', index_col=0)
df
# Out:
#                      제목     장르      작가  연재수      연재 시작일     마지막 연재일  \
# 0          차라리 빌런으로 살겠다  현대판타지     서인하  127  2024-03-02  2024-06-25
# 1            이상적 연출생활백서  현대판타지  자경(蔗境)   99  2024-03-12  2024-06-25
# 2       덕질하던 내가 천재보컬이었다  현대판타지     에레스  208  2023-08-09  2024-03-14
# 3             오빠가 천재였다.  현대판타지      시하   74  2024-03-31  2024-06-25
# 4       케이팝 씹어먹는 천재 작곡가  현대판타지     이신유  193  2023-12-13  2024-06-25
# ...                 ...    ...     ...  ...         ...         ...
# 9729            이리의 그림자    로맨스      무연   60  2015-09-14  2026-09-14
# 9730  미친 남주들과 같은 반이 되었다    로맨스      하뮴  217  2009-02-23  2013-02-24
# 9731          연우에서 연우까지    로맨스     은지필   52  2029-05-17  2029-05-17
# 9732               가유서부    로맨스    요이천하  859  2007-04-22  2007-04-22
# 9733        마녀가 사랑을 할 때    로맨스     서미선   26  2018-04-14  2011-06-14
#
#             Site
# 0         Munpia
# 1         Munpia
# 2         Munpia
# 3         Munpia
# 4         Munpia
# ...          ...
# 9729  Kakao_Page
# 9730  Kakao_Page
# 9731  Kakao_Page
# 9732  Kakao_Page
# 9733  Kakao_Page
#
# [9734 rows x 7 columns]

# %%
df.Site.unique()
# Out:
# array(['Munpia', 'NaverSeries', 'Kakao_Page'], dtype=object)

# %%
df[(df.장르 == '로맨스판타지') & (df.Site == 'NaverSeries')]
# Out:
#                        제목      장르    작가  연재수      연재 시작일     마지막 연재일  \
# 1335        나를 혐오하세요, 공작님  로맨스판타지   이초원  139  2024-04-03  2024-06-27
# 1337     언니, 이번 생엔 내가 왕비야  로맨스판타지  레팔진프  602  2020-12-06  2024-06-27
# 1367        죽음 뒤에 알게 된 것들  로맨스판타지   은라겸  204  2023-12-09  2024-06-27
# 1388       벗어 주시겠습니까, 공작님  로맨스판타지   루비체  188  2023-12-28  2024-06-27
# 1389         악연이 끝나고 난 후,  로맨스판타지  햇빛가루   96  2024-05-08  2024-06-27
# ...                   ...     ...   ...  ...         ...         ...
# 8037         악역이 내게 미쳐버렸다  로맨스판타지   김라체  149  2023-08-20  2023-12-17
# 8039         릴리스의 관 외전 추가  로맨스판타지    해말  169  2019-01-30  2019-07-21
# 8044  더는 당신의 악녀로 살지 않겠습니다  로맨스판타지   임홀리  181  2023-06-16  2023-11-01
# 8047   부도덕한 악역 황후에 빙의했습니다  로맨스판타지  달가듯이  205  2022-04-20  2022-08-03
# 8048          마른 가지에 바람처럼  로맨스판타지   달새울  230  2017-09-29  2021-02-19
#
#              Site
# 1335  NaverSeries
# 1337  NaverSeries
# 1367  NaverSeries
# 1388  NaverSeries
# 1389  NaverSeries
# ...           ...
# 8037  NaverSeries
# 8039  NaverSeries
# 8044  NaverSeries
# 8047  NaverSeries
# 8048  NaverSeries
#
# [947 rows x 7 columns]
