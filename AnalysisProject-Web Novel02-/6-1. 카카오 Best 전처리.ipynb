# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False

import pandas as pd

# %%
df = pd.read_csv('./data/Kakao_장르별_Top.txt', index_col=0)
df
# Out:
#                     제목   장르     작가       조회수        댓글       연재수    연재 시작일  \
# 1               마법을 품다  판타지     양강    311.2만  전체 1,100    전체 131  24.06.05
# 2          천재 궁수의 스트리밍  판타지    멍멍킴        2억  전체 15.2만    전체 979  21.02.09
# 3         변경백 서자는 황제였다  판타지    기준석  9,391.6만  전체 10.5만    전체 812  21.11.17
# 4     마법학교 마법사로 살아가는 법  판타지  글쓰는기계      1.8억  전체 16.7만  전체 1,075  21.08.17
# 5      달빛조각사: 아빠는 전설이다  판타지    남희성    956.5만  전체 6,723    전체 125  23.12.07
# ...                ...  ...    ...       ...       ...       ...       ...
# 1782               19금  로맨스    19금       19금       19금       19금       19금
# 1783               19금  로맨스    19금       19금       19금       19금       19금
# 1784               19금  로맨스    19금       19금       19금       19금       19금
# 1785               19금  로맨스    19금       19금       19금       19금       19금
# 1786               19금  로맨스    19금       19금       19금       19금       19금
#
#         최신 연재일    평점
# 1     24.06.26   9.6
# 2     24.06.26   9.9
# 3     24.06.26  10.0
# 4     24.06.26   9.9
# 5     24.06.25   9.5
# ...        ...   ...
# 1782       19금   19금
# 1783       19금   19금
# 1784       19금   19금
# 1785       19금   19금
# 1786       19금   19금
#
# [1786 rows x 9 columns]

# %%
# 19금 제거
index=df.loc[df.제목 == '19금'].index
df.drop(index, inplace=True)
df
# Out:
#                      제목   장르     작가       조회수        댓글       연재수    연재 시작일  \
# 1                마법을 품다  판타지     양강    311.2만  전체 1,100    전체 131  24.06.05
# 2           천재 궁수의 스트리밍  판타지    멍멍킴        2억  전체 15.2만    전체 979  21.02.09
# 3          변경백 서자는 황제였다  판타지    기준석  9,391.6만  전체 10.5만    전체 812  21.11.17
# 4      마법학교 마법사로 살아가는 법  판타지  글쓰는기계      1.8억  전체 16.7만  전체 1,075  21.08.17
# 5       달빛조각사: 아빠는 전설이다  판타지    남희성    956.5만  전체 6,723    전체 125  23.12.07
# ...                 ...  ...    ...       ...       ...       ...       ...
# 1769            이리의 그림자  로맨스     무연      8.1만     전체 67     전체 60  14.09.15
# 1775  미친 남주들과 같은 반이 되었다  로맨스     하뮴    764.1만  전체 9,201    전체 217  23.02.09
# 1777  연우에서 연우까지[단독 선공개]  로맨스    은지필     24.6만    전체 131     전체 52  17.05.29
# 1780               가유서부  로맨스   요이천하     55.1만    전체 255    전체 859  22.04.07
# 1781        마녀가 사랑을 할 때  로맨스    서미선     84.8만    전체 281     전체 26  14.04.18
#
#         최신 연재일    평점
# 1     24.06.26   9.6
# 2     24.06.26   9.9
# 3     24.06.26  10.0
# 4     24.06.26   9.9
# 5     24.06.25   9.5
# ...        ...   ...
# 1769  14.09.26   9.4
# 1775  24.02.13   9.8
# 1777  17.05.29   9.8
# 1780  22.04.07   9.6
# 1781  14.06.11   9.3
#
# [1410 rows x 9 columns]

# %%
patterns = [
    r'\[단행본\]', r'\[독점\]', r'\[연재\]', r'\[선공개\]', r'\[오디오드라마\]',
    r'\[개정판\-단독선연재\]', r'\[개정판\]', r'\[무적행 개정판\]', r'\[완결\]', r'\[단독 선공개\]',
    r'\[단독선공개\]', r'\[|\]'
]

for pattern in patterns:
    df['제목'] = df['제목'].str.replace(pattern, '', regex=True).str.strip()
df
# Out:
#                      제목   장르     작가       조회수        댓글       연재수    연재 시작일  \
# 1                마법을 품다  판타지     양강    311.2만  전체 1,100    전체 131  24.06.05
# 2           천재 궁수의 스트리밍  판타지    멍멍킴        2억  전체 15.2만    전체 979  21.02.09
# 3          변경백 서자는 황제였다  판타지    기준석  9,391.6만  전체 10.5만    전체 812  21.11.17
# 4      마법학교 마법사로 살아가는 법  판타지  글쓰는기계      1.8억  전체 16.7만  전체 1,075  21.08.17
# 5       달빛조각사: 아빠는 전설이다  판타지    남희성    956.5만  전체 6,723    전체 125  23.12.07
# ...                 ...  ...    ...       ...       ...       ...       ...
# 1769            이리의 그림자  로맨스     무연      8.1만     전체 67     전체 60  14.09.15
# 1775  미친 남주들과 같은 반이 되었다  로맨스     하뮴    764.1만  전체 9,201    전체 217  23.02.09
# 1777          연우에서 연우까지  로맨스    은지필     24.6만    전체 131     전체 52  17.05.29
# 1780               가유서부  로맨스   요이천하     55.1만    전체 255    전체 859  22.04.07
# 1781        마녀가 사랑을 할 때  로맨스    서미선     84.8만    전체 281     전체 26  14.04.18
#
#         최신 연재일    평점
# 1     24.06.26   9.6
# 2     24.06.26   9.9
# 3     24.06.26  10.0
# 4     24.06.26   9.9
# 5     24.06.25   9.5
# ...        ...   ...
# 1769  14.09.26   9.4
# 1775  24.02.13   9.8
# 1777  17.05.29   9.8
# 1780  22.04.07   9.6
# 1781  14.06.11   9.3
#
# [1410 rows x 9 columns]

# %%
# 제목이 중복되는 자료 제거
df=df.drop_duplicates('제목', keep='first', ignore_index=True)
df.제목.value_counts() # 중복값 확인
# Out:
# 마법을 품다                 1
# 내 안에 요괴가 산다            1
# 영웅이 없는 세계에서            1
# 호랑낭자 뎐                 1
# 퇴마 검사 진청단              1
#                       ..
# 귀신 찍는 PD님              1
# 세자 저하 아이돌하신다           1
# 무한 자본, 내 맘대로 세상 만들기    1
# 재벌가 막둥이는 만능천재          1
# 마녀가 사랑을 할 때            1
# Name: 제목, Length: 1365, dtype: int64

# %%
# '전체' 문자열 제거 및 공백 제거
df['댓글'] = df['댓글'].str.replace('전체', '', regex=True).str.strip()

# '만'과 '억' 단위 처리
df['댓글'] = df['댓글'].str.replace(r'(\d+\.\d+)만', lambda x: x.group(1).replace('.', '') + '000', regex=True)
df['댓글'] = df['댓글'].str.replace(r'(\d+)만', lambda x: x.group(1) + '0000', regex=True)
df['댓글'] = df['댓글'].str.replace(r'(\d+\.\d+)억', lambda x: x.group(1).replace('.', '') + '0000000', regex=True)
df['댓글'] = df['댓글'].str.replace(r'(\d+)억', lambda x: x.group(1) + '00000000', regex=True)

# 공백 및 불필요한 문자 제거
df['댓글'] = df['댓글'].str.replace('.', '', regex=True).str.strip()
df['댓글'] = df['댓글'].str.replace(',', '', regex=True).str.strip()

# 연재수 처리
df['연재수'] = df['연재수'].str.replace('전체', '', regex=True).str.strip()
df['연재수'] = df['연재수'].str.replace(',', '', regex=True).str.strip()

# 조회수 처리
df['조회수'] = df['조회수'].str.replace('전체', '', regex=True).str.strip()
df['조회수'] = df['조회수'].str.replace(r'(\d+\.\d+)만', lambda x: x.group(1).replace('.', '') + '000', regex=True)
df['조회수'] = df['조회수'].str.replace(r'(\d+)만', lambda x: x.group(1) + '0000', regex=True)
df['조회수'] = df['조회수'].str.replace(r'(\d+\.\d+)억', lambda x: x.group(1).replace('.', '') + '0000000', regex=True)
df['조회수'] = df['조회수'].str.replace(r'(\d+)억', lambda x: x.group(1) + '00000000', regex=True)
df['조회수'] = df['조회수'].str.replace(',', '', regex=True).str.strip()

# 연재 시작일 및 최신 연재일 처리
df['연재 시작일'] = df['연재 시작일'].str.replace(r'[()]', '', regex=True).str.strip()
df['최신 연재일'] = df['최신 연재일'].str.replace(r'[()]', '', regex=True).str.strip()

# %%
df.조회수 = df.조회수.astype(int)
df.연재수 = df.연재수.astype(int)
df.댓글 = df.댓글.astype(int)
df.평점 = df.평점.astype(float)
df['연재 시작일'] = pd.to_datetime(df['연재 시작일'])
df['최신 연재일'] = pd.to_datetime(df['최신 연재일'])

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1365 entries, 0 to 1364
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      1365 non-null   object
#  1   장르      1365 non-null   object
#  2   작가      1365 non-null   object
#  3   조회수     1365 non-null   int32
#  4   댓글      1365 non-null   int32
#  5   연재수     1365 non-null   int32
#  6   연재 시작일  1365 non-null   datetime64[ns]
#  7   최신 연재일  1365 non-null   datetime64[ns]
#  8   평점      1365 non-null   float64
# dtypes: datetime64[ns](2), float64(1), int32(3), object(3)
# memory usage: 80.1+ KB
#                      제목   장르     작가        조회수      댓글   연재수     연재 시작일  \
# 0                마법을 품다  판타지     양강    3112000    1100   131 2005-06-24
# 1           천재 궁수의 스트리밍  판타지    멍멍킴  200000000  152000   979 2009-02-21
# 2          변경백 서자는 황제였다  판타지    기준석   93916000  105000   812 2017-11-21
# 3      마법학교 마법사로 살아가는 법  판타지  글쓰는기계  180000000  167000  1075 2017-08-21
# 4       달빛조각사: 아빠는 전설이다  판타지    남희성    9565000    6723   125 2007-12-23
# ...                 ...  ...    ...        ...     ...   ...        ...
# 1360            이리의 그림자  로맨스     무연      81000      67    60 2015-09-14
# 1361  미친 남주들과 같은 반이 되었다  로맨스     하뮴    7641000    9201   217 2009-02-23
# 1362          연우에서 연우까지  로맨스    은지필     246000     131    52 2029-05-17
# 1363               가유서부  로맨스   요이천하     551000     255   859 2007-04-22
# 1364        마녀가 사랑을 할 때  로맨스    서미선     848000     281    26 2018-04-14
#
#          최신 연재일    평점
# 0    2026-06-24   9.6
# 1    2026-06-24   9.9
# 2    2026-06-24  10.0
# 3    2026-06-24   9.9
# 4    2025-06-24   9.5
# ...         ...   ...
# 1360 2026-09-14   9.4
# 1361 2013-02-24   9.8
# 1362 2029-05-17   9.8
# 1363 2007-04-22   9.6
# 1364 2011-06-14   9.3
#
# [1365 rows x 9 columns]

# %%
print(df['장르'].value_counts())

# 드라마 항목의 인덱스
index_num = df[df.장르 == '드라마'].index

# 장르와 개수
genres = ['현대판타지', '판타지', '무협', '로맨스판타지', '로맨스']
counts = [39, 39, 39, 39, 40]

# 드라마 항목 분배 # '현대판타지',0:39 , '판타지', 39:78 ~ 
start_idx = 0
for genre, count in zip(genres, counts):
    end_idx = start_idx + count
    df.loc[index_num[start_idx:end_idx], '장르'] = genre
    start_idx = end_idx
# Out:
# 현대판타지     293
# 판타지       290
# 무협        288
# 로맨스판타지    251
# 드라마       196
# 로맨스        47
# Name: 장르, dtype: int64

# %%
print(df['장르'].value_counts())
# Out:
# 현대판타지     332
# 판타지       329
# 무협        327
# 로맨스판타지    290
# 로맨스        87
# Name: 장르, dtype: int64

# %%
df
# Out:
#                      제목   장르     작가        조회수      댓글   연재수     연재 시작일  \
# 0                마법을 품다  판타지     양강    3112000    1100   131 2005-06-24
# 1           천재 궁수의 스트리밍  판타지    멍멍킴  200000000  152000   979 2009-02-21
# 2          변경백 서자는 황제였다  판타지    기준석   93916000  105000   812 2017-11-21
# 3      마법학교 마법사로 살아가는 법  판타지  글쓰는기계  180000000  167000  1075 2017-08-21
# 4       달빛조각사: 아빠는 전설이다  판타지    남희성    9565000    6723   125 2007-12-23
# ...                 ...  ...    ...        ...     ...   ...        ...
# 1360            이리의 그림자  로맨스     무연      81000      67    60 2015-09-14
# 1361  미친 남주들과 같은 반이 되었다  로맨스     하뮴    7641000    9201   217 2009-02-23
# 1362          연우에서 연우까지  로맨스    은지필     246000     131    52 2029-05-17
# 1363               가유서부  로맨스   요이천하     551000     255   859 2007-04-22
# 1364        마녀가 사랑을 할 때  로맨스    서미선     848000     281    26 2018-04-14
#
#          최신 연재일    평점
# 0    2026-06-24   9.6
# 1    2026-06-24   9.9
# 2    2026-06-24  10.0
# 3    2026-06-24   9.9
# 4    2025-06-24   9.5
# ...         ...   ...
# 1360 2026-09-14   9.4
# 1361 2013-02-24   9.8
# 1362 2029-05-17   9.8
# 1363 2007-04-22   9.6
# 1364 2011-06-14   9.3
#
# [1365 rows x 9 columns]

# %%
df.to_csv('./data/K_Best.txt')
